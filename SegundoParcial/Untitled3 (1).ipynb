# %% [markdown]
# # **Universidad Autonoma del Estado de México**

# %% [markdown]
# ## **Centro Universitario UAEM Zumpango**

# %% [markdown]
# ### Licenciatura en Ingenieria en Computación

# %% [markdown]
# #### Yair Uriel Flores Hidalgo
# #### Hazem Alvarez Rodriguez

# %% [markdown]
# ##### ![image.png](attachment:d4083d69-5cca-4143-b426-7fd09776c62e.png)

# %%
import numpy as np

A = np.matrix([[2, 3],[1, -2]])
b = np.matrix([[8],[-10]])

print("This is A \n",A)
print("This is b \n", b)

x=(A**-1)*b
print("Inverse A-1\n", x)

print (np.linalg.det(A))
# Out:
# This is A
#  [[ 2  3]
#  [ 1 -2]]
# This is b
#  [[  8]
#  [-10]]
# Inverse A-1
#  [[-2.]
#  [ 4.]]

# %% [markdown]
# ###### Usamos Numpy para calcular los determinantes en Python. Veamos un ejercicio en el que vamos a calcular el determinante de la siguiente matriz A: A = (9)
#
# ###### Como es lógico, el determinante de dicha matriz A de orden 1 va a ser el único valor que contiene dicha matriz.

# %%
#determinantes en Python
import numpy as np

A = np.array ([[9]])
print (A.shape)

print (np.linalg.det (A))
# Out:
# (1, 1)
# 9.000000000000002

# %% [markdown]
# ###### **Ese residuo infinitesimal es un redondeo de las operaciones en bytes.**

# %% [markdown]
# #### **Orden**
# ###### Cuando se habla de orden en una matriz, nos referimos al tamaño m X n de la matriz. En las matrices cuadradas m = n.
#
# ###### Calcula el determinante de la matriz de segundo orden B:

# %% [markdown]
# # ![image.png](attachment:f4e2cef3-a6d6-4ff9-b76d-0250f6868304.png)

# %% [markdown]
# ###### Aplicando la definición, obtenemos que:
#
# ### **|B| = a11 . a22 – a21 a12**
#
# ### **|B| = 4 . 0 – (-2) . (-1) = -2**
#
# ###### Por lo tanto:

# %%
#determinantes en Python
B = np.array ([[4,   -1],
                         [-2,   0]])

np.linalg.det (B)
# Out:
# -2.0

# %% [markdown]
# ##### Calcula el determinante de la matriz de tercer orden C:

# %% [markdown]
# # ![image.png](attachment:b199679d-cb4c-4f89-add7-eb34a68fb7bc.png)

# %%
#determinantes en Python
C = np.array ([[5,   0,   2],
                         [3,   1,   1],
                         [0,   1,   2]])

np.linalg.det (C)
# Out:
# 11.000000000000002

# %%
import numpy as np

A4 = np.matrix([[3, 2, -1],[2, -2,4] , [-1, 1/2, -1]])
b4 = np.matrix([[1],[-2] , [0]])

print("This is A \n",A4)
print("This is b \n", b4)

x=(A4**-1)*b4
print("Inverse A-1\n", x)

print (np.linalg.det(A4))
# Out:
# This is A
#  [[ 3.   2.  -1. ]
#  [ 2.  -2.   4. ]
#  [-1.   0.5 -1. ]]
# This is b
#  [[ 1]
#  [-2]
#  [ 0]]
# Inverse A-1
#  [[ 1.]
#  [-2.]
#  [-2.]]
# -3.0000000000000036

# %% [markdown]
# # ![Imagen de WhatsApp 2024-11-11 a las 11.55.28_bfc2c92b.jpg](attachment:5dc7f29e-3d75-437b-b044-2656fa428d41.jpg)

# %% [markdown]
# ### ![Imagen de WhatsApp 2024-11-11 a las 12.07.24_4d9d3640.jpg](attachment:efd17835-e7fc-4788-9684-707d2be6cdfd.jpg)

# %% [markdown]
# #### **Ejercicio 1**

# %%
import numpy as np

B= np.matrix([[4, -1],[ -2, 0 ] ])

print("This is B \n",B)

print (" Determinante: ")
print (np.linalg.det(B))
# Out:
# This is B
#  [[ 4 -1]
#  [-2  0]]
# This is c
#  [[5 0 2]
#  [3 1 1]
#  [0 1 2]]
#  Determinante:
# -2.0

# %% [markdown]
# #### **Ejercicio 2**

# %%
import numpy as np
c = np.matrix([[5, 0 , 2],[3 , 1 , 1 ] , [ 0 , 1 , 2]])
print("This is c \n", c)

print (" Determinante: ")
print (np.linalg.det(c))
# Out:
# This is c
#  [[5 0 2]
#  [3 1 1]
#  [0 1 2]]
#  Determinante:
# 11.000000000000002

# %% [markdown]
# #### **Ejercicio 3**

# %%
A = np.matrix([[3, 2, -1] , [2,-2,4], [-1,1/2,1]])
b = np.matrix([[1],[-2],[0]])

x = (A**-1)*b
print("Matriz Inversa ", x)
print("Determinante de A", np.linalg.det(A))
# Out:
# Matriz Inversa  [[-0.04347826]
#  [ 0.43478261]
#  [-0.26086957]]
# Determinante de A -23.00000000000001
